# %%
import numpy as np
from matplotlib import pyplot as plt
import h5py
import zeus

# %%
fn_b1 = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_b1_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_b1_chain_1.npy']
fn_biases = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_biases_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_biases_chain_1.npy']
fn_ocdm = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_omega_cdm_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_omega_cdm_chain_1.npy']
fn_cosmo = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_cosmo_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_mono_cosmo_chain_1.npy']
fn_b1_pk = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_b1_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_b1_chain_1.npy']
fn_biases_pk = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_biases_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_biases_chain_1.npy']
fn_ocdm_pk = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_omega_cdm_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_omega_cdm_chain_1.npy']
fn_test = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_test_chain_0.npy',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_test_chain_1.npy']
fn_test_ivanov = ['/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_test_ivanov_chain_0.h5',
         '/home/rneveux/fit_test/BOSS_DR12_NGC_z3_pk_test_ivanov_chain_1.h5']

# %%
samples=[]
for i in range(2):
    with h5py.File(fn_test_ivanov[i], "r") as hf:
        samples.append(np.copy(hf['samples']))
        logprob_samples = np.copy(hf['logprob'])
sample = np.concatenate(samples,axis=1)

# %%
chain_b1 = np.concatenate([np.load(fn_b1[i]) for i in range(2)])
chain_biases = np.concatenate([np.load(fn_biases[i]) for i in range(2)])
chain_ocdm = np.concatenate([np.load(fn_ocdm[i]) for i in range(2)])
chain_cosmo = np.concatenate([np.load(fn_cosmo[i]) for i in range(2)])
chain_b1_pk = np.concatenate([np.load(fn_b1_pk[i]) for i in range(2)])
chain_biases_pk = np.concatenate([np.load(fn_biases_pk[i]) for i in range(2)])
chain_ocdm_pk = np.concatenate([np.load(fn_ocdm_pk[i]) for i in range(2)])
chain_test = np.concatenate([np.load(fn_test[i]) for i in range(2)])
#chain_test_ivanov = np.concatenate([np.load(fn_test_ivanov[i]) for i in range(2)])
#len(chain_test_ivanov)

# %%
for i in range(sample.shape[2]):
    plt.hist(sample[750:,:,i],bins=100,histtype='step',density=True)
    print(np.mean(sample[750:,:,i]),' pm ',np.std(sample[750:,:,i]))
    plt.show()
# Out:
# 0.12996514751827182  pm  0.023337624372173883
# 0.7612976847036576  pm  0.09815943664369532
# 2.479204742741527  pm  0.7648436687567997
# 2.731774384720851  pm  0.9900106126759004
# -1.331478416987244  pm  3.060562990176004
# -0.7202257088080621  pm  1.8447158996611868
# 13.497594005231921  pm  55.44842312507078
# -1.958411836754741  pm  51.17650253718798
# 729.3575004094555  pm  2812.1327799265787
# 1.0014333038874053  pm  1.2389706825216242

# %%
plt.hist(chain_b1,bins=20,histtype='step',density=True)
plt.hist(chain_b1_pk,bins=20,histtype='step',density=True)
# Out:
# (array([ 2.00357121,  3.00535681,  2.00357121,  9.01607044, 13.02321285,
#         20.03571208, 34.06071053, 40.07142416, 44.07856657, 52.0928514 ,
#         39.06963855, 37.06606735, 36.06428174, 26.0464257 , 18.03214087,
#         16.02856966,  5.00892802,  3.00535681,  0.        ,  1.0017856 ]),
#  array([2.05944338, 2.06193892, 2.06443446, 2.06693001, 2.06942555,
#         2.0719211 , 2.07441664, 2.07691218, 2.07940773, 2.08190327,
#         2.08439882, 2.08689436, 2.0893899 , 2.09188545, 2.09438099,
#         2.09687654, 2.09937208, 2.10186762, 2.10436317, 2.10685871,
#         2.10935426]),
#  [<matplotlib.patches.Polygon at 0x7f9f675edeb0>])

# %%
print('mono: ',np.mean(chain_b1),' pm ',np.std(chain_b1))
print('full: ',np.mean(chain_b1_pk),' pm ',np.std(chain_b1_pk))
# Out:
# mono:  2.0691040675642527  pm  0.009453655369967813
# full:  2.083805283291551  pm  0.00819848338986304

# %%
for i in range(chain_biases.shape[1]):
    #plt.hist(chain_biases[:,i],bins=40,histtype='step',density=True)
    plt.hist(chain_biases_pk[:,i],bins=40,histtype='step',density=True)
    print('mono: ',np.mean(chain_biases[:,i]),' pm ',np.std(chain_biases[:,i]))
    print('full: ',np.mean(chain_biases_pk[:,i]),' pm ',np.std(chain_biases_pk[:,i]))
    plt.show()
# Out:
# mono:  3.37625606218922  pm  2.350210514038762
# full:  1.9195100548823465  pm  0.7962875971722637
# mono:  1.8212130594391382  pm  6.008590583899877
# full:  -1.19644634887022  pm  5.691464365590216
# mono:  -0.15914386902320543  pm  6.658114709087781
# full:  0.6115593216169182  pm  2.7307534234820343
# mono:  -1.3040019157808314  pm  6.625497171641763
# full:  -1.0066489751509948  pm  5.762587658646443
# mono:  -6.044917585568943  pm  59.134617041648184
# full:  3.078487068838149  pm  51.80034203045432
# mono:  -9.002602821253758  pm  65.35543915552579
# full:  -6.113401778842616  pm  53.80959501596034
# mono:  -16.39449106411229  pm  54.418380476461714
# full:  6.910819629969064  pm  65.1642567958943
# mono:  194.4052561086034  pm  600.6692601092296
# full:  152.81807113710187  pm  523.2172319222377
# mono:  -424.24672695509065  pm  1312.0378890955917
# full:  2.479232078985356  pm  1.6925821380716868

# %%
fig, axes = zeus.cornerplot(chain_test_ivanov);
# Out:
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# ...

# %%
fig, axes = zeus.cornerplot(chain_biases_pk);
# Out:
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# ...

# %%
plt.hist(chain_ocdm,bins=20,histtype='step')
# Out:
# (array([ 1.,  1.,  1.,  6.,  7., 19., 22., 37., 40., 44., 44., 42., 34.,
#         31., 27., 20.,  9.,  9.,  2.,  4.]),
#  array([0.138018  , 0.13837957, 0.13874114, 0.13910271, 0.13946428,
#         0.13982585, 0.14018742, 0.14054899, 0.14091056, 0.14127213,
#         0.1416337 , 0.14199527, 0.14235684, 0.14271841, 0.14307998,
#         0.14344155, 0.14380312, 0.14416469, 0.14452625, 0.14488782,
#         0.14524939]),
#  [<matplotlib.patches.Polygon at 0x7fa932c0c760>])

# %%
fig, axes = zeus.cornerplot(chain_cosmo);
# Out:
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# /usr/local/anaconda/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   cset = contour_func(
# ...

# %%
len(chain_biases_pk)
# Out:
# 3600

# %%
for i in range(chain_test.shape[1]):
    plt.hist(chain_test[:,i],bins=40,histtype='step',density=True)
    print(np.mean(chain_test[:,i]),' pm ',np.std(chain_test[:,i]))
    plt.show()
# Out:
# 0.202047460391024  pm  0.08116926935472453
# 3.076446552999631  pm  0.21700259525682583
# 0.9581968994352121  pm  0.04307898565571249
# 2.5655397822164656  pm  2.056136325507104
# -0.7221518206062807  pm  5.983268094249853
# 19.50608568576431  pm  65.24474104900075
# 97.4657029775275  pm  937.7924584344577

# %%
plt.hist(chain_biases[:,-1],bins=40,histtype='step',density=True, range=[-1,5])
plt.hist(chain_biases_pk[:,-1],bins=40,histtype='step',density=True, range=[-1,5])
# Out:
# (array([0.07293946, 0.        , 0.10211524, 0.23340627, 0.14587892,
#         0.07293946, 0.1896426 , 0.39387309, 0.26258206, 0.11670314,
#         0.1896426 , 0.11670314, 0.08752735, 0.07293946, 0.02917578,
#         0.24799416, 0.08752735, 0.07293946, 0.1896426 , 0.35010941,
#         0.11670314, 0.24799416, 0.20423049, 0.1896426 , 1.00656455,
#         0.16046681, 0.        , 0.04376368, 0.07293946, 0.04376368,
#         0.02917578, 0.01458789, 0.        , 0.01458789, 0.21881838,
#         0.43763676, 0.67104303, 0.11670314, 0.02917578, 0.01458789]),
#  array([-1.  , -0.85, -0.7 , -0.55, -0.4 , -0.25, -0.1 ,  0.05,  0.2 ,
#          0.35,  0.5 ,  0.65,  0.8 ,  0.95,  1.1 ,  1.25,  1.4 ,  1.55,
#          1.7 ,  1.85,  2.  ,  2.15,  2.3 ,  2.45,  2.6 ,  2.75,  2.9 ,
#          3.05,  3.2 ,  3.35,  3.5 ,  3.65,  3.8 ,  3.95,  4.1 ,  4.25,
#          4.4 ,  4.55,  4.7 ,  4.85,  5.  ]),
#  [<matplotlib.patches.Polygon at 0x7f9f66891d30>])

# %%
a =np.load(fn_test_ivanov[0])

# %%
len(a)
# Out:
# 1000

# %%
plt.hist(chain_ocdm_pk[:,0],bins=40,histtype='step',density=True)
print(np.mean())
# Out:
# (array([ 23.94234842,   0.        ,   0.        ,  11.97117421,
#          35.91352263,  23.94234842,  83.79821946,  71.82704525,
#          71.82704525, 119.71174209,  95.76939367, 119.71174209,
#         143.6540905 , 215.48113576, 287.30818101, 275.3370068 ,
#         275.3370068 , 311.25052942, 335.19287784, 299.27935522,
#         275.3370068 , 275.3370068 , 143.6540905 , 167.59643892,
#         203.50996155, 131.6829163 , 119.71174209, 227.45230996,
#         131.6829163 , 119.71174209,  23.94234842,  35.91352263,
#          47.88469683,  59.85587104,   0.        ,   0.        ,
#           0.        ,  11.97117421,   0.        ,  11.97117421]),
#  array([0.1404198 , 0.14062864, 0.14083747, 0.14104631, 0.14125514,
#         0.14146398, 0.14167281, 0.14188165, 0.14209048, 0.14229932,
#         0.14250815, 0.14271699, 0.14292582, 0.14313466, 0.14334349,
#         0.14355233, 0.14376116, 0.14397   , 0.14417883, 0.14438767,
# ...
